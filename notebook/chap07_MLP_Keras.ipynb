# %% [markdown]
# <a href="https://colab.research.google.com/github/alsrn36533/pdm02/blob/main/notebook/chap07_MLP_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MLP:Keras

# %% [markdown]
# ## mini-batch 구현 (중요함★)

# %%
import numpy as np
import tensorflow as tf

# 데이터를 학습 데이터와 테스트 데이터로 나눈다. 
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print(x_train.shape,y_train.shape)
print(y_train[:10])
print(x_train.shape,y_test.shape)
print(y_test[:10])

data_size = x_train.shape[0]
batch_size = 12	# 배치 크기

selected = np.random.choice(data_size, batch_size)
print(selected)
x_batch = x_train[selected]
y_batch = y_train[selected]
x_batch.shape,y_batch.shape
# Out:
# (60000, 28, 28) (60000,)
# [5 0 4 1 9 2 1 3 1 4]
# (60000, 28, 28) (10000,)
# [7 2 1 0 4 1 4 9 5 9]
# [ 6380 46079 52746 20515 30126 58326  9635 57539 19311 12618 20309 33062]
# ((12, 28, 28), (12,))

# %% [markdown]
# ## mini-batch : XOR using MLP

# %%
import numpy as np
# XOR solution by MLP

# 시그모이드 함수
def actf(x):
	return 1/(1+np.exp(-x))

# 시그모이드 함수의 미분치
def actf_deriv(x):
	    return x*(1-x)

# 입력유닛의 개수, 은닉유닛의 개수, 출력유닛의 개수
inputs, hiddens, outputs = 2, 2, 1
learning_rate = 0.5

# 훈련 입력과 출력
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
T = np.array([[0], [1], [1], [0]])

# 가중치를 –1.0에서 1.0 사이의 난수로 초기화한다.
W1 = 2*np.random.random((inputs, hiddens))-1   
W2 = 2*np.random.random((hiddens, outputs))-1  
B1 = np.zeros(hiddens)   
B2 = np.zeros(outputs)   

# 순방향 전파 계산
def predict(x):
        layer0 = x			# 입력을 layer0에 대입한다. 
        Z1 = np.dot(layer0, W1)+B1	# 행렬의 곱을 계산한다. 
        layer1 = actf(Z1)		# 활성화 함수를 적용한다. 
        Z2 = np.dot(layer1, W2)+B2	# 행렬의 곱을 계산한다. 
        layer2 = actf(Z2)		# 활성화 함수를 적용한다. 
        return layer0, layer1, layer2
    
# 역방향 전파 계산
def fit():
    global W1, W2, B1, B2
    for i in range(60000):
            layer0, layer1, layer2 = predict(X) # input-batch-size = 4
            layer2_error = layer2-T

            layer2_delta = layer2_error*actf_deriv(layer2)
            layer1_error = np.dot(layer2_delta, W2.T)
            layer1_delta = layer1_error*actf_deriv(layer1)
            
            W2 += -learning_rate*np.dot(layer1.T, layer2_delta)/4.0 # 4개의 입력에 대한 평균 기울기
            W1 += -learning_rate*np.dot(layer0.T, layer1_delta)/4.0
            B2 += -learning_rate*np.sum(layer2_delta, axis=0)/4.0
            B1 += -learning_rate*np.sum(layer1_delta, axis=0)/4.0

def test():
    for x, y in zip(X, T):
        x = np.reshape(x, (1, -1))		# 하나여도 2차원 형태이어야 한다.
        layer0, layer1, layer2 = predict(x)
        print(x, y, layer2)

fit()
test()
W1,W2
B1,B2
# Out:
# [[0 0]] [0] [[0.01247431]]
# [[0 1]] [1] [[0.98691379]]
# [[1 0]] [1] [[0.98686511]]
# [[1 1]] [0] [[0.01616885]]
# (array([7.36573344, 2.72591104]), array([-4.86817477]))

# %% [markdown]
# ---
# # Tensorflow-Keras
# ---

# %% [markdown]
# ## MLP XOR in Keras
# - 1-은닉층
# - 2-은닉층

# %%
import numpy as np
import tensorflow as tf

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units=2, input_shape=(2,), activation='sigmoid')) #①
model.add(tf.keras.layers.Dense(units=1,  activation='sigmoid')) #②		
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.SGD(lr=0.3)) 

model.summary()
 
X = np.array([[0, 0],[0, 1],[1, 0],[1, 1]])
y = np.array([[0], [1], [1], [0]])

model.fit(X, y, batch_size=1, epochs=10000, verbose =2)

print(model.predict(X))
# [[0.0156148 ]
#  [0.98538893]
#  [0.9820687 ]
#  [0.01398213]]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 7503/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7504/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7505/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7506/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7507/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7508/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7509/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 7510/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7511/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7512/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7513/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7514/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7515/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7516/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7517/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7518/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7519/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7520/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7521/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7522/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7523/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7524/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7525/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7526/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7527/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7528/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7529/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7530/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7531/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7532/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7533/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7534/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7535/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7536/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7537/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7538/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7539/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7540/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7541/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7542/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7543/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7544/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7545/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7546/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7547/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7548/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7549/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7550/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7551/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7552/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7553/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7554/10000
# 4/4 - 0s - loss: 0.1402 - 19ms/epoch - 5ms/step
# Epoch 7555/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7556/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7557/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7558/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7559/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7560/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7561/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7562/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7563/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7564/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7565/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7566/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7567/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7568/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7569/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7570/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7571/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7572/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7573/10000
# 4/4 - 0s - loss: 0.1403 - 15ms/epoch - 4ms/step
# Epoch 7574/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7575/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7576/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7577/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7578/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7579/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7580/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7581/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 7582/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7583/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7584/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7585/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7586/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 4ms/step
# Epoch 7587/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7588/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7589/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7590/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7591/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7592/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7593/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7594/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7595/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7596/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7597/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7598/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7599/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 7600/10000
# 4/4 - 0s - loss: 0.1403 - 19ms/epoch - 5ms/step
# Epoch 7601/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7602/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7603/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7604/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7605/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7606/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7607/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7608/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7609/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7610/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7611/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7612/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7613/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7614/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7615/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7616/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7617/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7618/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7619/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7620/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7621/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7622/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7623/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7624/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7625/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7626/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7627/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7628/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7629/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7630/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7631/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7632/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 7633/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7634/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7635/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7636/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7637/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7638/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7639/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7640/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7641/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7642/10000
# 4/4 - 0s - loss: 0.1404 - 9ms/epoch - 2ms/step
# Epoch 7643/10000
# 4/4 - 0s - loss: 0.1404 - 15ms/epoch - 4ms/step
# Epoch 7644/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7645/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 3ms/step
# Epoch 7646/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 7647/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7648/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7649/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7650/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7651/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7652/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7653/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 7654/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 7655/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7656/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7657/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7658/10000
# 4/4 - 0s - loss: 0.1404 - 13ms/epoch - 3ms/step
# Epoch 7659/10000
# 4/4 - 0s - loss: 0.1404 - 19ms/epoch - 5ms/step
# Epoch 7660/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7661/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7662/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7663/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7664/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7665/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7666/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7667/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7668/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7669/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7670/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7671/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7672/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7673/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7674/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7675/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7676/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7677/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7678/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7679/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7680/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7681/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7682/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7683/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7684/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7685/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7686/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7687/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7688/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7689/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7690/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7691/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7692/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7693/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7694/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7695/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7696/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7697/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7698/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7699/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7700/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7701/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7702/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7703/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7704/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7705/10000
# 4/4 - 0s - loss: 0.1402 - 20ms/epoch - 5ms/step
# Epoch 7706/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7707/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7708/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7709/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7710/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7711/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7712/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7713/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7714/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7715/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7716/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7717/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7718/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7719/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7720/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7721/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7722/10000
# 4/4 - 0s - loss: 0.1404 - 15ms/epoch - 4ms/step
# Epoch 7723/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7724/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7725/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7726/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7727/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7728/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7729/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7730/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7731/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7732/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7733/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7734/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7735/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7736/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7737/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7738/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7739/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7740/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7741/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7742/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7743/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7744/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7745/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7746/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7747/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7748/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7749/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7750/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7751/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7752/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7753/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7754/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7755/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7756/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7757/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7758/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7759/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7760/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7761/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7762/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7763/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7764/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7765/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7766/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7767/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 3ms/step
# Epoch 7768/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7769/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7770/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7771/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7772/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7773/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7774/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7775/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7776/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7777/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7778/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7779/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7780/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7781/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7782/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7783/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7784/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7785/10000
# 4/4 - 0s - loss: 0.1403 - 18ms/epoch - 4ms/step
# Epoch 7786/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7787/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7788/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7789/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7790/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7791/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7792/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7793/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7794/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7795/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 7796/10000
# 4/4 - 0s - loss: 0.1402 - 22ms/epoch - 5ms/step
# Epoch 7797/10000
# 4/4 - 0s - loss: 0.1402 - 21ms/epoch - 5ms/step
# Epoch 7798/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 7799/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7800/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7801/10000
# 4/4 - 0s - loss: 0.1402 - 20ms/epoch - 5ms/step
# Epoch 7802/10000
# 4/4 - 0s - loss: 0.1402 - 20ms/epoch - 5ms/step
# Epoch 7803/10000
# 4/4 - 0s - loss: 0.1402 - 19ms/epoch - 5ms/step
# Epoch 7804/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7805/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7806/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7807/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7808/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 7809/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7810/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7811/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7812/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7813/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7814/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7815/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7816/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7817/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 7818/10000
# 4/4 - 0s - loss: 0.1403 - 17ms/epoch - 4ms/step
# Epoch 7819/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7820/10000
# 4/4 - 0s - loss: 0.1404 - 14ms/epoch - 3ms/step
# Epoch 7821/10000
# 4/4 - 0s - loss: 0.1404 - 13ms/epoch - 3ms/step
# Epoch 7822/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7823/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7824/10000
# 4/4 - 0s - loss: 0.1404 - 17ms/epoch - 4ms/step
# Epoch 7825/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7826/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 4ms/step
# Epoch 7827/10000
# 4/4 - 0s - loss: 0.1403 - 17ms/epoch - 4ms/step
# Epoch 7828/10000
# 4/4 - 0s - loss: 0.1404 - 14ms/epoch - 4ms/step
# Epoch 7829/10000
# 4/4 - 0s - loss: 0.1404 - 15ms/epoch - 4ms/step
# Epoch 7830/10000
# 4/4 - 0s - loss: 0.1405 - 18ms/epoch - 5ms/step
# Epoch 7831/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7832/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7833/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7834/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7835/10000
# 4/4 - 0s - loss: 0.1402 - 19ms/epoch - 5ms/step
# Epoch 7836/10000
# 4/4 - 0s - loss: 0.1402 - 19ms/epoch - 5ms/step
# Epoch 7837/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7838/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7839/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7840/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7841/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7842/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7843/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7844/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7845/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7846/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7847/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7848/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7849/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 7850/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7851/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 4ms/step
# Epoch 7852/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7853/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7854/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 7855/10000
# 4/4 - 0s - loss: 0.1405 - 11ms/epoch - 3ms/step
# Epoch 7856/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7857/10000
# 4/4 - 0s - loss: 0.1402 - 8ms/epoch - 2ms/step
# Epoch 7858/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7859/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 7860/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7861/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7862/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7863/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7864/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 7865/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7866/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7867/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7868/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7869/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7870/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7871/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7872/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7873/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7874/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7875/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7876/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7877/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7878/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7879/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7880/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 7881/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7882/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7883/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 7884/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 7885/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 7886/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7887/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7888/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7889/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7890/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7891/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 7892/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 7893/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7894/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7895/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7896/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7897/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7898/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7899/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7900/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7901/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7902/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7903/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7904/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 7905/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7906/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7907/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7908/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7909/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7910/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7911/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7912/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7913/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 7914/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7915/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7916/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7917/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7918/10000
# 4/4 - 0s - loss: 0.1403 - 17ms/epoch - 4ms/step
# Epoch 7919/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7920/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 7921/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7922/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7923/10000
# 4/4 - 0s - loss: 0.1404 - 13ms/epoch - 3ms/step
# Epoch 7924/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 7925/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7926/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7927/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 7928/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7929/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7930/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 7931/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7932/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7933/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7934/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 4ms/step
# Epoch 7935/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7936/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7937/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7938/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 3ms/step
# Epoch 7939/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7940/10000
# 4/4 - 0s - loss: 0.1404 - 13ms/epoch - 3ms/step
# Epoch 7941/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7942/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 7943/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7944/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7945/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7946/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 7947/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7948/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7949/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7950/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7951/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7952/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7953/10000
# 4/4 - 0s - loss: 0.1403 - 17ms/epoch - 4ms/step
# Epoch 7954/10000
# 4/4 - 0s - loss: 0.1404 - 18ms/epoch - 4ms/step
# Epoch 7955/10000
# 4/4 - 0s - loss: 0.1404 - 14ms/epoch - 4ms/step
# Epoch 7956/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7957/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 3ms/step
# Epoch 7958/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 7959/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7960/10000
# 4/4 - 0s - loss: 0.1403 - 15ms/epoch - 4ms/step
# Epoch 7961/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7962/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 7963/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7964/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 7965/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7966/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 7967/10000
# 4/4 - 0s - loss: 0.1405 - 13ms/epoch - 3ms/step
# Epoch 7968/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7969/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7970/10000
# 4/4 - 0s - loss: 0.1404 - 15ms/epoch - 4ms/step
# Epoch 7971/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7972/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7973/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7974/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 7975/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7976/10000
# 4/4 - 0s - loss: 0.1404 - 14ms/epoch - 3ms/step
# Epoch 7977/10000
# 4/4 - 0s - loss: 0.1404 - 14ms/epoch - 4ms/step
# Epoch 7978/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7979/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7980/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7981/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7982/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 7983/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 7984/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 7985/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7986/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 7987/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7988/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7989/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7990/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7991/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7992/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7993/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7994/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7995/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7996/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 7997/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 7998/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 7999/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8000/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8001/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8002/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 8003/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 8004/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8005/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8006/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8007/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8008/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8009/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8010/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8011/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8012/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8013/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8014/10000
# 4/4 - 0s - loss: 0.1403 - 15ms/epoch - 4ms/step
# Epoch 8015/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8016/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8017/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8018/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8019/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8020/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8021/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8022/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8023/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8024/10000
# 4/4 - 0s - loss: 0.1405 - 10ms/epoch - 2ms/step
# Epoch 8025/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8026/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8027/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8028/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8029/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8030/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8031/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 8032/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8033/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8034/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8035/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8036/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8037/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8038/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8039/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8040/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8041/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 8042/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 8043/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8044/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8045/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 8046/10000
# 4/4 - 0s - loss: 0.1404 - 13ms/epoch - 3ms/step
# Epoch 8047/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8048/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8049/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 8050/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8051/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8052/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8053/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8054/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8055/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8056/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8057/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8058/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 8059/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 8060/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8061/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8062/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8063/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8064/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8065/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 8066/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8067/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8068/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8069/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8070/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8071/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8072/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8073/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8074/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8075/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8076/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8077/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8078/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8079/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8080/10000
# 4/4 - 0s - loss: 0.1403 - 13ms/epoch - 3ms/step
# Epoch 8081/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8082/10000
# 4/4 - 0s - loss: 0.1404 - 18ms/epoch - 4ms/step
# Epoch 8083/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8084/10000
# 4/4 - 0s - loss: 0.1405 - 11ms/epoch - 3ms/step
# Epoch 8085/10000
# 4/4 - 0s - loss: 0.1405 - 10ms/epoch - 3ms/step
# Epoch 8086/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8087/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8088/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8089/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8090/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8091/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8092/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 8093/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8094/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8095/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8096/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 8097/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 8098/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8099/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8100/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8101/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8102/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8103/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8104/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 8105/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8106/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8107/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8108/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8109/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8110/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8111/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8112/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8113/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 8114/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8115/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8116/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8117/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8118/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8119/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8120/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8121/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 8122/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 8123/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8124/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8125/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8126/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8127/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8128/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8129/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8130/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8131/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8132/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8133/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8134/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8135/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8136/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8137/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8138/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8139/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8140/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8141/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8142/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8143/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8144/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8145/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8146/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 8147/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8148/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8149/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 8150/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 8151/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8152/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8153/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8154/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 3ms/step
# Epoch 8155/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8156/10000
# 4/4 - 0s - loss: 0.1403 - 15ms/epoch - 4ms/step
# Epoch 8157/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8158/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8159/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8160/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8161/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8162/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8163/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8164/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8165/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 8166/10000
# 4/4 - 0s - loss: 0.1404 - 12ms/epoch - 3ms/step
# Epoch 8167/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8168/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8169/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8170/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8171/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8172/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8173/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8174/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 8175/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 8176/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8177/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 8178/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8179/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8180/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8181/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8182/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8183/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8184/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8185/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8186/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8187/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8188/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8189/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8190/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8191/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8192/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8193/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8194/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8195/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8196/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8197/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8198/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8199/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8200/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 8201/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 8202/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8203/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 8204/10000
# 4/4 - 0s - loss: 0.1405 - 10ms/epoch - 3ms/step
# Epoch 8205/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8206/10000
# 4/4 - 0s - loss: 0.1403 - 14ms/epoch - 4ms/step
# Epoch 8207/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8208/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8209/10000
# 4/4 - 0s - loss: 0.1403 - 9ms/epoch - 2ms/step
# Epoch 8210/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8211/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8212/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 8213/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8214/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8215/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8216/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 8217/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 3ms/step
# Epoch 8218/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8219/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8220/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8221/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 8222/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 8223/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 2ms/step
# Epoch 8224/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 8225/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8226/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 3ms/step
# Epoch 8227/10000
# ...
# Epoch 9756/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9757/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 9758/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9759/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9760/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9761/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9762/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9763/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 4ms/step
# Epoch 9764/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9765/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9766/10000
# 4/4 - 0s - loss: 0.1402 - 16ms/epoch - 4ms/step
# Epoch 9767/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9768/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 3ms/step
# Epoch 9769/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9770/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9771/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9772/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9773/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9774/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9775/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9776/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9777/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9778/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9779/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9780/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9781/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 9782/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 9783/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9784/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9785/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9786/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9787/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9788/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9789/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9790/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9791/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9792/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9793/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9794/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9795/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9796/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9797/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 9798/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9799/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9800/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9801/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9802/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9803/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9804/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9805/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9806/10000
# 4/4 - 0s - loss: 0.1403 - 10ms/epoch - 3ms/step
# Epoch 9807/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9808/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9809/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9810/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9811/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9812/10000
# 4/4 - 0s - loss: 0.1403 - 17ms/epoch - 4ms/step
# Epoch 9813/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9814/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9815/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9816/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9817/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9818/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9819/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9820/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9821/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9822/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9823/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9824/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9825/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9826/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 3ms/step
# Epoch 9827/10000
# 4/4 - 0s - loss: 0.1401 - 17ms/epoch - 4ms/step
# Epoch 9828/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9829/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9830/10000
# 4/4 - 0s - loss: 0.1402 - 14ms/epoch - 4ms/step
# Epoch 9831/10000
# 4/4 - 0s - loss: 0.1403 - 18ms/epoch - 5ms/step
# Epoch 9832/10000
# 4/4 - 0s - loss: 0.1403 - 15ms/epoch - 4ms/step
# Epoch 9833/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9834/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9835/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9836/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9837/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9838/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9839/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9840/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9841/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9842/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9843/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9844/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9845/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9846/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9847/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9848/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9849/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9850/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9851/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9852/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9853/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9854/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9855/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9856/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9857/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9858/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9859/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9860/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9861/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9862/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9863/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9864/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9865/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9866/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9867/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9868/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9869/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9870/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9871/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9872/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9873/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9874/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 4ms/step
# Epoch 9875/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9876/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9877/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9878/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9879/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9880/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9881/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9882/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9883/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9884/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9885/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9886/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9887/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9888/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9889/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9890/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9891/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9892/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9893/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9894/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9895/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9896/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9897/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9898/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9899/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9900/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9901/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9902/10000
# 4/4 - 0s - loss: 0.1402 - 13ms/epoch - 3ms/step
# Epoch 9903/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9904/10000
# 4/4 - 0s - loss: 0.1403 - 12ms/epoch - 3ms/step
# Epoch 9905/10000
# 4/4 - 0s - loss: 0.1403 - 16ms/epoch - 4ms/step
# Epoch 9906/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 9907/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 9908/10000
# 4/4 - 0s - loss: 0.1404 - 11ms/epoch - 3ms/step
# Epoch 9909/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9910/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9911/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9912/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9913/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9914/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9915/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9916/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9917/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9918/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9919/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9920/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9921/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9922/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9923/10000
# 4/4 - 0s - loss: 0.1401 - 17ms/epoch - 4ms/step
# Epoch 9924/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9925/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9926/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9927/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9928/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9929/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9930/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9931/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9932/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9933/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9934/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9935/10000
# 4/4 - 0s - loss: 0.1402 - 18ms/epoch - 5ms/step
# Epoch 9936/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9937/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9938/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9939/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9940/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9941/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9942/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9943/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9944/10000
# 4/4 - 0s - loss: 0.1402 - 12ms/epoch - 3ms/step
# Epoch 9945/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9946/10000
# 4/4 - 0s - loss: 0.1403 - 11ms/epoch - 3ms/step
# Epoch 9947/10000
# 4/4 - 0s - loss: 0.1404 - 10ms/epoch - 2ms/step
# Epoch 9948/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9949/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9950/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9951/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9952/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9953/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9954/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9955/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9956/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9957/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9958/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9959/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9960/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 9961/10000
# 4/4 - 0s - loss: 0.1402 - 15ms/epoch - 4ms/step
# Epoch 9962/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9963/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9964/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 3ms/step
# Epoch 9965/10000
# 4/4 - 0s - loss: 0.1401 - 16ms/epoch - 4ms/step
# Epoch 9966/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 4ms/step
# Epoch 9967/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9968/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9969/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9970/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9971/10000
# 4/4 - 0s - loss: 0.1403 - 16ms/epoch - 4ms/step
# Epoch 9972/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9973/10000
# 4/4 - 0s - loss: 0.1401 - 14ms/epoch - 4ms/step
# Epoch 9974/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9975/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9976/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9977/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9978/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9979/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9980/10000
# 4/4 - 0s - loss: 0.1401 - 15ms/epoch - 4ms/step
# Epoch 9981/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9982/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9983/10000
# 4/4 - 0s - loss: 0.1401 - 12ms/epoch - 3ms/step
# Epoch 9984/10000
# 4/4 - 0s - loss: 0.1402 - 11ms/epoch - 3ms/step
# Epoch 9985/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9986/10000
# 4/4 - 0s - loss: 0.1402 - 17ms/epoch - 4ms/step
# Epoch 9987/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9988/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 3ms/step
# Epoch 9989/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 3ms/step
# Epoch 9990/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9991/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# Epoch 9992/10000
# 4/4 - 0s - loss: 0.1401 - 13ms/epoch - 3ms/step
# Epoch 9993/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 9994/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9995/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9996/10000
# 4/4 - 0s - loss: 0.1402 - 9ms/epoch - 2ms/step
# Epoch 9997/10000
# 4/4 - 0s - loss: 0.1401 - 9ms/epoch - 2ms/step
# Epoch 9998/10000
# 4/4 - 0s - loss: 0.1401 - 11ms/epoch - 3ms/step
# Epoch 9999/10000
# 4/4 - 0s - loss: 0.1402 - 10ms/epoch - 2ms/step
# Epoch 10000/10000
# 4/4 - 0s - loss: 0.1401 - 10ms/epoch - 2ms/step
# [[0.01345665]
#  [0.9847348 ]
#  [0.4944975 ]
#  [0.49530125]]

# %%
# 2-은닉층
import numpy as np
import tensorflow as tf

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units=2, input_shape=(2,), activation='sigmoid')) #①
model.add(tf.keras.layers.Dense(units=4, activation='sigmoid')) #
model.add(tf.keras.layers.Dense(units=1,  activation='sigmoid')) #		
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.SGD(lr=0.3)) 

model.summary()

X = np.array([[0, 0],[0, 1],[1, 0],[1, 1]])
y = np.array([[0], [1], [1], [0]])

model.fit(X, y, batch_size=1, epochs=10000, verbose=0)

print(model.predict(X))

# [[0.00956685]
#  [0.9900732 ]
#  [0.9919224 ]
#  [0.00822851]]
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 2)                 6
#
#  dense_3 (Dense)             (None, 4)                 12
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 23
# Trainable params: 23
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# [[0.00712317]
#  [0.98856175]
#  [0.9885467 ]
#  [0.01835654]]

# %% [markdown]
# ## Mnist model using Keras
# 1. Sequential model
# 2. Functional model
# 3. Subclassing model

# %% [markdown]
# ### Data loading

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
import numpy as np

(train_images, train_labels), (test_images, test_labels)	= tf.keras.datasets.mnist.load_data()

print(train_images.shape)

print(train_labels)
print(test_images.shape)

plt.imshow(train_images[0], cmap="Greys")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# [5 0 4 ... 5 6 8]
# (10000, 28, 28)

# %% [markdown]
# ### Data preprocessing
# - Reshape
# - Normalization
# - one-hot encoding

# %%
#
# dataset: train, test
#
train_images = train_images.reshape((60000, 784))
train_images = train_images.astype('float32') / 255.0

test_images = test_images.reshape((10000, 784))
test_images = test_images.astype('float32') / 255.0

train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

print(train_images.shape,train_labels.shape)
# Out:
# (60000, 784) (60000, 10)

# %% [markdown]
# ## 1. Sequential model

# %%
# model
model = models.Sequential()

model.add(layers.Dense(512, activation='relu', input_shape=(784,)))
model.add(layers.Dense(10, activation='sigmoid'))

model.compile(optimizer='rmsprop',
                loss='mse',
                metrics=['accuracy'])

# %%
# Training with history
history = model.fit(train_images, train_labels, epochs=5, batch_size=128, verbose=2)
# Training graph
loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, acc, 'r', label='Accuracy')
plt.xlabel('epochs')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Epoch 1/5
# 469/469 - 2s - loss: 0.0157 - accuracy: 0.9179 - 2s/epoch - 5ms/step
# Epoch 2/5
# 469/469 - 1s - loss: 0.0063 - accuracy: 0.9657 - 1s/epoch - 2ms/step
# Epoch 3/5
# 469/469 - 1s - loss: 0.0044 - accuracy: 0.9765 - 1s/epoch - 2ms/step
# Epoch 4/5
# 469/469 - 1s - loss: 0.0034 - accuracy: 0.9827 - 1s/epoch - 2ms/step
# Epoch 5/5
# 469/469 - 1s - loss: 0.0028 - accuracy: 0.9862 - 1s/epoch - 2ms/step

# %%
# test
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('테스트 정확도:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0038 - accuracy: 0.9789
# 테스트 정확도: 0.9789000153541565

# %%
# Test with new image
import cv2 as cv

image = cv.imread('test.png', cv.IMREAD_GRAYSCALE)
image = cv.resize(image, (28, 28))
image = image.astype('float32')
# plt.imshow(image.reshape(28, 28),cmap='Greys')
# plt.show()
image = image.reshape(1, 784)
image = 255-image
image /= 255.0

plt.imshow(image.reshape(28, 28),cmap='Greys')
plt.show()

pred = model.predict(image.reshape(1, 784), batch_size=1)
print("추정된 숫자=", pred.argmax())
print(np.sum(pred))
# Out:
# 추정된 숫자= 2
# 1.2838187

# %% [markdown]
# ## 2.Functional model

# %%
#
# Model2 - Functional
#

inputs = layers.Input(shape=(784,))

x = layers.Dense(512, activation='relu')(inputs)
output = layers.Dense(10, activation='sigmoid')(x)

model = models.Model(inputs=inputs, outputs=output)

model.compile(optimizer='rmsprop',
                loss='mse',
                metrics=['accuracy'])

# %%
# Training with history
history = model.fit(train_images, train_labels, epochs=5, batch_size=128, verbose=2)
loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, acc, 'r', label='Accuracy')
plt.xlabel('epochs')
plt.ylabel('loss/acc')
plt.show()

# test
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('테스트 정확도:', test_acc)
# Out:
# Epoch 1/5
# 469/469 - 1s - loss: 0.0159 - accuracy: 0.9168 - 1s/epoch - 3ms/step
# Epoch 2/5
# 469/469 - 1s - loss: 0.0062 - accuracy: 0.9666 - 1s/epoch - 2ms/step
# Epoch 3/5
# 469/469 - 1s - loss: 0.0044 - accuracy: 0.9766 - 1s/epoch - 2ms/step
# Epoch 4/5
# 469/469 - 1s - loss: 0.0034 - accuracy: 0.9825 - 1s/epoch - 2ms/step
# Epoch 5/5
# 469/469 - 1s - loss: 0.0027 - accuracy: 0.9865 - 1s/epoch - 2ms/step
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9807
# 테스트 정확도: 0.9807000160217285

# %% [markdown]
# ## 3. Subclassing model

# %%
#
# Model3 - Class
#

class MnistMLP(models.Model):
    
    def __init__(self, num_classes):
        super(MnistMLP, self).__init__(name='mlp')
        self.num_classes = num_classes
        
        self.dense1 = layers.Dense(512, activation='relu')
        self.dense2 = layers.Dense(10, activation='softmax')
        
    def call(self, inputs):
        x = self.dense1(inputs)
        return self.dense2(x)
    
# model
model = MnistMLP(num_classes=10)

model.compile(optimizer='rmsprop',
                loss='mse',
                metrics=['accuracy'])

# %%
# Training with history
history = model.fit(train_images, train_labels, epochs=5, batch_size=128,verbose=2)

loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, acc, 'r', label='Accuracy')
plt.xlabel('epochs')
plt.ylabel('loss/acc')
plt.show()

# test
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('테스트 정확도:', test_acc)
# Out:
# Epoch 1/5
# 469/469 - 2s - loss: 0.0122 - accuracy: 0.9216 - 2s/epoch - 3ms/step
# Epoch 2/5
# 469/469 - 1s - loss: 0.0054 - accuracy: 0.9661 - 1s/epoch - 2ms/step
# Epoch 3/5
# 469/469 - 1s - loss: 0.0037 - accuracy: 0.9773 - 1s/epoch - 3ms/step
# Epoch 4/5
# 469/469 - 1s - loss: 0.0028 - accuracy: 0.9829 - 1s/epoch - 3ms/step
# Epoch 5/5
# 469/469 - 1s - loss: 0.0022 - accuracy: 0.9866 - 1s/epoch - 2ms/step
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9792
# 테스트 정확도: 0.979200005531311

# %% [markdown]
# ---
# # Hyperparameter search
# - Grid search
# ---

# %%
# !pip install scikeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikeras
#   Downloading scikeras-0.9.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: importlib-metadata>=3 in /usr/local/lib/python3.7/dist-packages (from scikeras) (5.0.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.7/dist-packages (from scikeras) (21.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikeras) (1.0.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=0.21->scikeras) (3.0.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.21.6)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.9.0

# %%
# import numpy as np 
# import matplotlib.pyplot as plt 
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
# from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier
# OS warning cure
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# 데이터 세트 준비
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)
                             
# 신경망 모델 구축
def build_model():
    network = tf.keras.models.Sequential()
    network.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
    network.add(tf.keras.layers.Dense(10, activation='sigmoid'))

    network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
    return network

# 하이퍼 매개변수 딕셔너리
param_grid = {
              'epochs':[1, 2, 3],	# 에포크 수: 1, 2, 3
              'batch_size':[32, 64, 100]	# 배치 크기: 32, 64, 100
             }

# 케라스 모델을 scikeras에서 사용하도록 포장한다. 
model = KerasClassifier(model = build_model, verbose=1)

## Elapsed time start
import time
start = time.time()

# 그리드 검색
gs = GridSearchCV(
    estimator=model,
    param_grid=param_grid, 
    cv=3, 
    # n_jobs=-1 # comment this line to avoid out-of-memory
)

# 그리드 검색 결과 출력
grid_result = gs.fit(train_images, train_labels)

## Elapsed time end
end = time.time()
print('Elapsed time:', end - start) # Elapsed time: 122.5, 189.5

print(grid_result.best_score_) # 0.9725, 0.9711
print(grid_result.best_params_) # {'batch_size': 64, 'epochs': 3}
# Out:
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.2379 - accuracy: 0.9293
# 625/625 [==============================] - 1s 1ms/step
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2331 - accuracy: 0.9313
# 625/625 [==============================] - 1s 1ms/step
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2384 - accuracy: 0.9293
# 625/625 [==============================] - 1s 1ms/step
# Epoch 1/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2408 - accuracy: 0.9285
# Epoch 2/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1032 - accuracy: 0.9698
# 625/625 [==============================] - 1s 1ms/step
# Epoch 1/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2344 - accuracy: 0.9296
# Epoch 2/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1011 - accuracy: 0.9696
# 625/625 [==============================] - 1s 1ms/step
# Epoch 1/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2359 - accuracy: 0.9296
# Epoch 2/2
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.0997 - accuracy: 0.9704
# 625/625 [==============================] - 1s 1ms/step
# Epoch 1/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2441 - accuracy: 0.9281
# Epoch 2/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1056 - accuracy: 0.9680
# Epoch 3/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.0728 - accuracy: 0.9783
# 625/625 [==============================] - 1s 1ms/step
# Epoch 1/3
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.2349 - accuracy: 0.9315
# Epoch 2/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1015 - accuracy: 0.9702
# Epoch 3/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.0692 - accuracy: 0.9802
# 625/625 [==============================] - 1s 2ms/step
# Epoch 1/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2380 - accuracy: 0.9283
# Epoch 2/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1007 - accuracy: 0.9709
# Epoch 3/3
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.0696 - accuracy: 0.9801
# 625/625 [==============================] - 1s 1ms/step
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2657 - accuracy: 0.9230
# 313/313 [==============================] - 0s 1ms/step
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2616 - accuracy: 0.9259
# 313/313 [==============================] - 0s 1ms/step
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2647 - accuracy: 0.9226
# 313/313 [==============================] - 0s 1ms/step
# Epoch 1/2
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2652 - accuracy: 0.9225
# Epoch 2/2
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1122 - accuracy: 0.9661
# 313/313 [==============================] - 0s 1ms/step
# Epoch 1/2
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2611 - accuracy: 0.9238
# Epoch 2/2
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1090 - accuracy: 0.9674
# 313/313 [==============================] - 0s 1ms/step
# Epoch 1/2
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2622 - accuracy: 0.9234
# Epoch 2/2
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1092 - accuracy: 0.9677
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2649 - accuracy: 0.9216
# Epoch 2/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1110 - accuracy: 0.9670
# Epoch 3/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.0732 - accuracy: 0.9775
# 313/313 [==============================] - 0s 1ms/step
# Epoch 1/3
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2606 - accuracy: 0.9229
# Epoch 2/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1112 - accuracy: 0.9671
# Epoch 3/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.0742 - accuracy: 0.9780
# 313/313 [==============================] - 0s 1ms/step
# Epoch 1/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2620 - accuracy: 0.9231
# Epoch 2/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.1080 - accuracy: 0.9682
# Epoch 3/3
# 625/625 [==============================] - 2s 2ms/step - loss: 0.0702 - accuracy: 0.9786
# 313/313 [==============================] - 0s 1ms/step
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2909 - accuracy: 0.9165
# 200/200 [==============================] - 0s 1ms/step
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2894 - accuracy: 0.9154
# 200/200 [==============================] - 0s 1ms/step
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2894 - accuracy: 0.9175
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/2
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2925 - accuracy: 0.9163
# Epoch 2/2
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1231 - accuracy: 0.9643
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/2
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2860 - accuracy: 0.9173
# Epoch 2/2
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1205 - accuracy: 0.9642
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/2
# 400/400 [==============================] - 2s 3ms/step - loss: 0.2889 - accuracy: 0.9175
# Epoch 2/2
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1200 - accuracy: 0.9646
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.9168
# Epoch 2/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1235 - accuracy: 0.9632
# Epoch 3/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0807 - accuracy: 0.9758
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2895 - accuracy: 0.9177
# Epoch 2/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1219 - accuracy: 0.9646
# Epoch 3/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0794 - accuracy: 0.9761
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2955 - accuracy: 0.9147
# Epoch 2/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1227 - accuracy: 0.9639
# Epoch 3/3
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0804 - accuracy: 0.9763
# 200/200 [==============================] - 0s 1ms/step
# Epoch 1/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2222 - accuracy: 0.9346
# Epoch 2/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0926 - accuracy: 0.9722
# Epoch 3/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0622 - accuracy: 0.9816
# Elapsed time: 172.40851497650146
# 0.9699333333333332
# {'batch_size': 64, 'epochs': 3}
